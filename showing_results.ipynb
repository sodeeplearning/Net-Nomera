# %%
import torch
import ST

# %%
aug_images = torch.load("Saved Tensors/Augmented images.pth")
seg_answers = torch.load("Saved Tensors/Segmentation answers.pth")

# %%
ST.imshow(aug_images[0])

# %%
ST.imshow(seg_answers[0].reshape((1, 270, 480)))
